# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\ariji\Downloads\sample.csv")

# %%
data
# Out:
#             Food Product Main Ingredient      Sweetener       Fat/Oil  \
# 0  Blueberry Protein Bar     Blueberries          Honey    Almond oil
# 1     Mango Chia Pudding           Mango  Coconut sugar  Coconut milk
# 2         Beetroot Chips        Beetroot            NaN     Olive oil
# 3   Pumpkin Spice Muffin         Pumpkin    Maple syrup        Butter
# 4            Lentil Soup         Lentils            NaN     Olive oil
# 5      Quinoa Sushi Roll          Quinoa            NaN   Avocado oil
# 6         Turmeric Latte        Turmeric     Date syrup   Coconut oil
# 7          Seaweed Snack         Seaweed            NaN    Sesame oil
# 8     Hazelnut Milkshake       Hazelnuts    Agave syrup  Hazelnut oil
# 9  Spicy Black Bean Wrap     Black Beans            NaN           NaN
#
#               Seasoning     Allergens  Price ($)  Customer rating (Out of 5)
# 0       Vanilla extract     Tree nuts       2.99                         4.2
# ...

# %%
data['Sweetener'].fillna('Unknown', inplace=True)
data['Fat/Oil'].fillna('Unknown', inplace=True)
data['Seasoning'].fillna('Unknown', inplace=True)
data['Allergens'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\ariji\AppData\Local\Temp\ipykernel_26880\55113914.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Sweetener'].fillna('Unknown', inplace=True)
# C:\Users\ariji\AppData\Local\Temp\ipykernel_26880\55113914.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data
# Out:
#             Food Product Main Ingredient      Sweetener       Fat/Oil  \
# 0  Blueberry Protein Bar     Blueberries          Honey    Almond oil
# 1     Mango Chia Pudding           Mango  Coconut sugar  Coconut milk
# 2         Beetroot Chips        Beetroot        Unknown     Olive oil
# 3   Pumpkin Spice Muffin         Pumpkin    Maple syrup        Butter
# 4            Lentil Soup         Lentils        Unknown     Olive oil
# 5      Quinoa Sushi Roll          Quinoa        Unknown   Avocado oil
# 6         Turmeric Latte        Turmeric     Date syrup   Coconut oil
# 7          Seaweed Snack         Seaweed        Unknown    Sesame oil
# 8     Hazelnut Milkshake       Hazelnuts    Agave syrup  Hazelnut oil
# 9  Spicy Black Bean Wrap     Black Beans        Unknown       Unknown
#
#               Seasoning     Allergens  Price ($)  Customer rating (Out of 5)
# 0       Vanilla extract     Tree nuts       2.99                         4.2
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import joblib

encoder = joblib.load(r'C:\Users\ariji\SafeBite\Models\encoder.pkl')
encoder
cat_cols=['Food Product','Main Ingredient','Sweetener','Fat/Oil','Seasoning','Allergens']
encoded_data = encoder.transform(data[cat_cols])
data=pd.concat([data.drop(cat_cols,axis=1),encoded_data],axis=1)

# %%
import joblib
model = joblib.load(r"C:\Users\ariji\SafeBite\Models\best_knn_model.pkl")

# %%
prediction=model.predict(data)

# %%
prediction
# Out:
# array([1, 1, 1, 0, 1, 0, 1, 1, 1, 1], dtype=int64)
